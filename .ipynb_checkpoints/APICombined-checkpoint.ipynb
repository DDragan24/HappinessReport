# %%
import requests
import numpy as np
import json
import pandas as pd
from pprint import pprint

HousingDF = pd.read_pickle('HousingDF.pkl')
resultsDF = pd.read_pickle('resultsDF.pkl')
SpendDF = pd.read_pickle('SpendDF.pkl')
EntertainDF = pd.read_pickle('EntertainDF.pkl')


from config import api_key
from matplotlib import pyplot as plt

# %%
HousingDF
# Out:
#    year  value
# 9  2012  16887
# 8  2013  17148
# 7  2014  17798
# 6  2015  18409
# 5  2016  18886
# 4  2017  19884
# 3  2018  20091
# 2  2019  20679
# 1  2020  21417
# 0  2021  22624

# %%
SpendDF
# Out:
#    year  value
# 8  2014   6759
# 7  2015   7023
# 6  2016   7203
# 5  2017   7729
# 4  2018   7923
# 3  2019   8169
# 2  2020   7310
# 1  2021   8289
# 0  2022   9343

# %%
resultsDF
# Out:
#      year    value  monthYear
# 119  2014  233.916 2014-01-01
# 118  2014  234.781 2014-02-01
# 117  2014  236.293 2014-03-01
# 116  2014  237.072 2014-04-01
# 115  2014  237.900 2014-05-01
# ..    ...      ...        ...
# 4    2023  307.026 2023-08-01
# 3    2023  307.789 2023-09-01
# 2    2023  307.671 2023-10-01
# 1    2023  307.051 2023-11-01
# 0    2023  306.746 2023-12-01
#
# [120 rows x 3 columns]

# %%
EntertainDF
# Out:
#    year  value
# 9  2013   2482
# 8  2014   2728
# 7  2015   2842
# 6  2016   2913
# 5  2017   3203
# 4  2018   3226
# 3  2019   3090
# 2  2020   2909
# 1  2021   3568
# 0  2022   3458

# %%
HousingExp = plt.plot(HousingDF['year'],HousingDF['value'],color='red',label="Housing Expenses")

EntertainExp = plt.plot(EntertainDF['year'],EntertainDF['value'],color='orange',label="Entertainment Expenses")

FoodExpenses = plt.plot(SpendDF['year'],SpendDF['value'],color='green',label="Food Expenses")


plt.title("Expenses On Home/Food compared with CPI")
plt.xlabel("Year")
plt.ylabel("Expenses Amount ($)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
HousingDF.plot('year','value',kind='line',color='red',label="Housing Expenses")

EntertainDF.plot('year','value',kind='line',color='orange',label="Entertainment Expenses")

SpendDF.plot('year','value',kind='line',color='green',label="Food Expenses")


plt.title("Expenses On Home/Food compared with CPI")
plt.xlabel("Year")
plt.ylabel("Expenses Amount ($)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
