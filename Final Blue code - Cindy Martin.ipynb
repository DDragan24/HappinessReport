# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st



# Study data files
US10yrhappy = "US10yearhappiness.csv"
Mexico10yrhappy = "Mexico10yearhappiness.csv"
Canada10yrhappy = "Canada10yearhappiness.csv"
Topandbottom="Topandbottom.csv"

# %%
# Read the mouse data and th"e" study results
US10yrhappy  = pd.read_csv("C:\\Desktop\\Project 1\\US10yearhappiness.csv")
Mexico10yrhappy  = pd.read_csv("C:\\Desktop\\Project 1\\Mexico10yearhappiness.csv")
Canada10yrhappy  = pd.read_csv("C:\\Desktop\\Project 1\\Canada10yearhappiness.csv")
Topandbottom = pd.read_csv("C:\\Desktop\\Project 1\\Topandbottom.csv")

# Combine the data into a single dataset
#study_data_complete= pd.merge(study_results, mouse_metadata, how="left", on="Mouse ID")
#Happy_complete=pd.merge(US10yrhappy, Mexico10yrhappy, how="left", on="Life Ladder")

# Display the data table for preview
US10yrhappy.head(11)
# Out:
#        Unnamed: 0  year  Life Ladder  Log GDP per capita  Social support  \
# 0   United States  2013        7.249              10.941           0.925
# 1   United States  2014        7.151              10.956           0.902
# 2   United States  2015        6.864              10.975           0.904
# 3   United States  2016        6.804              10.985           0.897
# 4   United States  2017        6.992              11.001           0.921
# 5   United States  2018        6.883              11.024           0.904
# 6   United States  2019        6.944              11.042           0.917
# 7   United States  2020        7.028              11.005           0.937
# 8   United States  2021        6.959              11.061           0.920
# 9   United States  2022        6.693              11.078           0.900
# 10  United States  2023        6.521              11.089           0.861
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
plt.plot(US10yrhappy["year"],
        US10yrhappy["Life Ladder"],
        color = "purple")
plt.title =("10 year  Happiness level of the United States")
plt.xlabel("Year")
plt.ylabel("Happiness Level")
plt.show()

# %%
Mexico10yrhappy.head(11)
# Out:
#    Unnamed: 0  year  Life Ladder  Log GDP per capita  Social support  \
# 0      Mexico  2013        7.443               9.844           0.759
# 1      Mexico  2014        6.680               9.860           0.782
# 2      Mexico  2015        6.236               9.880           0.761
# 3      Mexico  2016        6.824               9.895           0.893
# 4      Mexico  2017        6.410               9.905           0.800
# 5      Mexico  2018        6.550               9.917           0.858
# 6      Mexico  2019        6.432               9.907           0.852
# 7      Mexico  2020        5.964               9.816           0.779
# 8      Mexico  2021        5.991               9.857           0.779
# 9      Mexico  2022        7.038               9.881           0.858
# 10     Mexico  2023        7.006               9.900           0.868
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 0                              65.52                         0.739
# ...

# %%
plt.plot(Mexico10yrhappy["year"],
        Mexico10yrhappy["Life Ladder"],
        color = "green")
plt.title =("10 year  Happiness level of Mexico ")
plt.xlabel("Year")
plt.ylabel("Happiness Level")
plt.show()

# %%
Canada10yrhappy.head(11)
# Out:
#    Country name    year  Life Ladder  Log GDP per capita  Social support  \
# 0        Canada  2013.0        7.594              10.752           0.936
# 1        Canada  2014.0        7.304              10.770           0.918
# 2        Canada  2015.0        7.413              10.769           0.939
# 3        Canada  2016.0        7.245              10.768           0.924
# 4        Canada  2017.0        7.415              10.786           0.934
# 5        Canada  2018.0        7.175              10.799           0.923
# 6        Canada  2019.0        7.109              10.803           0.925
# 7        Canada  2020.0        7.025              10.740           0.931
# 8        Canada  2021.0        6.939              10.783           0.926
# 9        Canada  2022.0        6.918              10.799           0.929
# 10       Canada  2023.0        6.841              10.794           0.902
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
plt.plot(Canada10yrhappy["year"],
        Canada10yrhappy["Life Ladder"],
        color = "red")
plt.title =("10 year  Happiness level of the Canada")
plt.xlabel("Year")
plt.ylabel("Happiness Level")
plt.show()

# %%
import numpy as np
Country_name=Topandbottom["Life Ladder"]
overall.plot(kind="bar", 
          edgecolor = "Black")
x_labels =["Finland","Denmark", "Iceland", "Canada", "Mexico", "United States","Sierra Leone", "Lebanon", "Afghanistan"]
ticklocations=[value for value in np.arange(len(x_labels))]
plt.xlabel("Country name")
plt.ylabel("Happiness Level")
#plt.title("Overall Happiness")
plt.xticks(ticklocations, x_labels,rotation=90)
plt.show()

# %%
plt.plot(Canada10yrhappy["year"],
        Canada10yrhappy["Life Ladder"],
        color = "red")
plt.plot(Mexico10yrhappy["year"],
        Mexico10yrhappy["Life Ladder"],
        color = "green")
plt.plot(US10yrhappy["year"],
        US10yrhappy["Life Ladder"],
        color = "purple")
plt.title =("10 year  Happiness level of the Canada")
plt.xlabel("Year")
plt.ylabel("Happiness Level")
plt.show()

# %%
USyrCPI  = pd.read_csv("C:\\Desktop\\Project 1\\CPIUS.csv")
USyrCPI.head()
# Out:
#    Year    Value
# 0  2013  230.280
# 1  2014  233.916
# 2  2015  233.707
# 3  2016  236.916
# 4  2017  242.839

# %%
plt.plot(USyrCPI["Year"],
        USyrCPI["Value"],
        color = "black")
plt.title =("CPI index in the United States")
plt.xlabel("Year")
plt.ylabel("CPI")
plt.show()

# %%
CanadaCPI  = pd.read_csv("C:\\Desktop\\Project 1\\CanadaCPI.csv")
CanadaCPI.head()
# Out:
#        date  CPI_COMMON
# 0  1/1/2014         1.3
# 1  1/1/2015         1.9
# 2  1/1/2016         2.1
# 3  1/1/2017         1.2
# 4  1/1/2018         1.6

# %%
plt.plot(CanadaCPI["date"],
        CanadaCPI["CPI_COMMON"],
        color = "gray")
plt.title =("CPI index in Canada")
plt.xlabel("Year")

plt.ylabel("CPI")
plt.xticks(rotation=90)
plt.show()
